# %% [markdown]
# # Practical 1
# ## FDS

# %%
import pandas as pd
import numpy as np

# %%
my_dict={"Name":["a","b","c","d","e","f","g"],
        "Age":[22,34,56,75,23,43,33],
        "Designation":["VP","CEO","CFO","VP","VP","MD","IT"]}

# %%
df= pd.DataFrame(my_dict)

# %%
df
# Out:
#   Name  Age Designation
# 0    a   22          VP
# 1    b   34         CEO
# 2    c   56         CFO
# 3    d   75          VP
# 4    e   23          VP
# 5    f   43          MD
# 6    g   33          IT

# %%
df.to_csv("first.csv",index=False)

# %%
df_csv= pd.read_csv("first.csv")

# %%
df_csv
# Out:
#   Name  Age Designation
# 0    a   22          VP
# 1    b   34         CEO
# 2    c   56         CFO
# 3    d   75          VP
# 4    e   23          VP
# 5    f   43          MD
# 6    g   33          IT

# %%
student_df= pd.read_csv("student-mat - student-mat.csv")

# %%
student_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
(student_df["sex"].value_counts(normalize=True)*100).round(2)
# Out:
# F    52.66
# M    47.34
# Name: sex, dtype: float64

# %%
famsize=student_df["famsize"].unique().tolist()

# %%
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
student_df["age"].median()
# Out:
# 17.0

# %%
col_names=student_df.columns.tolist()

# %%
student_df.rename({"G1":"Grade1"},inplace=True,axis=1)

# %%
names=["Rob","Jay","Roy","Ajay","Ram"]
grades=[78,56,99,65,88]
bsc=[1,2,0,0,1]
msc=[1,1,0,3,1]
phd=[1,0,1,0,2]
degrees=zip(names,grades,bsc,msc,phd)
columns= ["Names","Grade","Bsc","Msc","Phd"]
df1= pd.DataFrame(data=degrees,columns=columns)
df1
# Out:
#   Names  Grade  Bsc  Msc  Phd
# 0   Rob     78    1    1    1
# 1   Jay     56    2    1    0
# 2   Roy     99    0    0    1
# 3  Ajay     65    0    3    0
# 4   Ram     88    1    1    2

# %%
grade_df= pd.read_excel("gradedata.xlsx",engine="openpyxl")

# %%
grade_df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                                address
# 0                 7379 Highland Rd. , Dublin, GA 31021
# 1                   8 Bayport St. , Honolulu, HI 96815
# ...

# %%
names=["Rob","Jay","Roy","Ajay","Ram"]
grades=[78,56,99,65,88]
gradelist=zip(names,grades)
df2= pd.DataFrame(gradelist,columns=["Names","Grades"])

# %%
df2.to_excel("second.xlsx",index=False)

# %%
xl_df= pd.read_excel("second.xlsx",engine="openpyxl")
xl_df
# Out:
#   Names  Grades
# 0   Rob      78
# 1   Jay      56
# 2   Roy      99
# 3  Ajay      65
# 4   Ram      88

# %% [markdown]
# # Day 2
# ## sqlite3

# %%
import sqlite3
con= sqlite3.connect("portal_mammals.sqlite")
cur= con.cursor()
for row in cur.execute('select * from species'):
    print(row)
con.close()
# Out:
# ('AB', 'Amphispiza', 'bilineata', 'Bird')
# ('AH', 'Ammospermophilus', 'harrisi', 'Rodent')
# ('AS', 'Ammodramus', 'savannarum', 'Bird')
# ('BA', 'Baiomys', 'taylori', 'Rodent')
# ('CB', 'Campylorhynchus', 'brunneicapillus', 'Bird')
# ('CM', 'Calamospiza', 'melanocorys', 'Bird')
# ('CQ', 'Callipepla', 'squamata', 'Bird')
# ('CS', 'Crotalus', 'scutalatus', 'Reptile')
# ('CT', 'Cnemidophorus', 'tigris', 'Reptile')
# ('CU', 'Cnemidophorus', 'uniparens', 'Reptile')
# ('CV', 'Crotalus', 'viridis', 'Reptile')
# ('DM', 'Dipodomys', 'merriami', 'Rodent')
# ('DO', 'Dipodomys', 'ordii', 'Rodent')
# ('DS', 'Dipodomys', 'spectabilis', 'Rodent')
# ('DX', 'Dipodomys', 'sp.', 'Rodent')
# ('EO', 'Eumeces', 'obsoletus', 'Reptile')
# ('GS', 'Gambelia', 'silus', 'Reptile')
# ('NL', 'Neotoma', 'albigula', 'Rodent')
# ('NX', 'Neotoma', 'sp.', 'Rodent')
# ('OL', 'Onychomys', 'leucogaster', 'Rodent')
# ('OT', 'Onychomys', 'torridus', 'Rodent')
# ('OX', 'Onychomys', 'sp.', 'Rodent')
# ...

# %%
con= sqlite3.connect("portal_mammals.sqlite")
cur= con.cursor()
#Return all results from query
cur.execute('select plot_id from plots where plot_type="Control"')
print(cur.fetchall())
#return first result of the query
cur.execute("select species from species where taxa='Bird'")
print(cur.fetchone())
# Out:
# [(2,), (4,), (8,), (11,), (12,), (14,), (17,), (22,)]
# ('bilineata',)

# %%
qdf= pd.read_sql_query("select * from surveys",con)
qdf.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
cars={"Brand":["Honda civic","Toyota corolla","Ford Focus","Audi A4"],
     "Price":[20000,39990,45000,70000]}
cars_df=pd.DataFrame(cars)
cars_df
# Out:
#             Brand  Price
# 0     Honda civic  20000
# 1  Toyota corolla  39990
# 2      Ford Focus  45000
# 3         Audi A4  70000

# %%
con2= sqlite3.connect("Testdb")
cur2=con2.cursor()
cur2.execute("create table cars(Brand text,Price number)")
con2.commit()

# %%
cars_df.to_sql('cars',con2,if_exists='replace',index=False)

# %%
cur2.execute("select Brand, max(Price) from cars")
cur2.fetchall()
# Out:
# [('Audi A4', 70000)]

# %%
studentId=["rj101","rj150","rj134","rj70"]
SName=["saurabh","Giftson","Vikas","Radha"]
LName=["Chavan","Paul","Bisoi","Rai"]
Department=["Bms","Bcom","BscCS","BscIT"]
Email=["100rabh@gmail.com","gift01@gmail.com","vik21@gmail.com","radha@gmail.com"]
stu_data=zip(studentId,SName,LName,Department,Email)

# %%
stu_df= pd.DataFrame(data=stu_data,columns=["studentId","SName","LName","Department","Email"])
stu_df
# Out:
#   studentId    SName   LName Department              Email
# 0     rj101  saurabh  Chavan        Bms  100rabh@gmail.com
# 1     rj150  Giftson    Paul       Bcom   gift01@gmail.com
# 2     rj134    Vikas   Bisoi      BscCS    vik21@gmail.com
# 3      rj70    Radha     Rai      BscIT    radha@gmail.com

# %%
stu_df.to_csv("student.csv")

# %% [markdown]
# # Day 3

# %%
state =pd.read_csv("US_violent_crime - US_violent_crime.csv")

# %%
state.head()
# Out:
#         State  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
def some_fun(x):
    return x*2

# %%
state.apply(some_fun)
# Out:
#                            State  Murder  Assault  UrbanPop  Rape
# 0                 AlabamaAlabama    26.4      472       116  42.4
# 1                   AlaskaAlaska    20.0      526        96  89.0
# 2                 ArizonaArizona    16.2      588       160  62.0
# 3               ArkansasArkansas    17.6      380       100  39.0
# 4           CaliforniaCalifornia    18.0      552       182  81.2
# 5               ColoradoColorado    15.8      408       156  77.4
# 6         ConnecticutConnecticut     6.6      220       154  22.2
# 7               DelawareDelaware    11.8      476       144  31.6
# 8                 FloridaFlorida    30.8      670       160  63.8
# 9                 GeorgiaGeorgia    34.8      422       120  51.6
# 10                  HawaiiHawaii    10.6       92       166  40.4
# 11                    IdahoIdaho     5.2      240       108  28.4
# 12              IllinoisIllinois    20.8      498       166  48.0
# ...

# %%
state.apply(lambda X: X*2)
# Out:
#                            State  Murder  Assault  UrbanPop  Rape
# 0                 AlabamaAlabama    26.4      472       116  42.4
# 1                   AlaskaAlaska    20.0      526        96  89.0
# 2                 ArizonaArizona    16.2      588       160  62.0
# 3               ArkansasArkansas    17.6      380       100  39.0
# 4           CaliforniaCalifornia    18.0      552       182  81.2
# 5               ColoradoColorado    15.8      408       156  77.4
# 6         ConnecticutConnecticut     6.6      220       154  22.2
# 7               DelawareDelaware    11.8      476       144  31.6
# 8                 FloridaFlorida    30.8      670       160  63.8
# 9                 GeorgiaGeorgia    34.8      422       120  51.6
# 10                  HawaiiHawaii    10.6       92       166  40.4
# 11                    IdahoIdaho     5.2      240       108  28.4
# 12              IllinoisIllinois    20.8      498       166  48.0
# ...

# %%
state.transform(func=lambda x: x*2)
# Out:
#                            State  Murder  Assault  UrbanPop  Rape
# 0                 AlabamaAlabama    26.4      472       116  42.4
# 1                   AlaskaAlaska    20.0      526        96  89.0
# 2                 ArizonaArizona    16.2      588       160  62.0
# 3               ArkansasArkansas    17.6      380       100  39.0
# 4           CaliforniaCalifornia    18.0      552       182  81.2
# 5               ColoradoColorado    15.8      408       156  77.4
# 6         ConnecticutConnecticut     6.6      220       154  22.2
# 7               DelawareDelaware    11.8      476       144  31.6
# 8                 FloridaFlorida    30.8      670       160  63.8
# 9                 GeorgiaGeorgia    34.8      422       120  51.6
# 10                  HawaiiHawaii    10.6       92       166  40.4
# 11                    IdahoIdaho     5.2      240       108  28.4
# 12              IllinoisIllinois    20.8      498       166  48.0
# ...

# %%
avg_murder= state.groupby("State")["Murder"].mean().reset_index(name="Avg_murder")
print(avg_murder)
# Out:
#              State  Avg_murder
# 0          Alabama        13.2
# 1           Alaska        10.0
# 2          Arizona         8.1
# 3         Arkansas         8.8
# 4       California         9.0
# 5         Colorado         7.9
# 6      Connecticut         3.3
# 7         Delaware         5.9
# 8          Florida        15.4
# 9          Georgia        17.4
# 10          Hawaii         5.3
# 11           Idaho         2.6
# 12        Illinois        10.4
# 13         Indiana         7.2
# 14            Iowa         2.2
# 15          Kansas         6.0
# 16        Kentucky         9.7
# 17       Louisiana        15.4
# 18           Maine         2.1
# 19        Maryland        11.3
# 20   Massachusetts         4.4
# 21        Michigan        12.1
# 22       Minnesota         2.7
# 23     Mississippi        16.1
# 24        Missouri         9.0
# 25         Montana         6.0
# 26        Nebraska         4.3
# 27          Nevada        12.2
# 28   New Hampshire         2.1
# ...

# %%
state.shape
# Out:
# (50, 5)

# %%
state.merge(avg_murder)
# Out:
#              State  Murder  Assault  UrbanPop  Rape  Avg_murder
# 0          Alabama    13.2      236        58  21.2        13.2
# 1           Alaska    10.0      263        48  44.5        10.0
# 2          Arizona     8.1      294        80  31.0         8.1
# 3         Arkansas     8.8      190        50  19.5         8.8
# 4       California     9.0      276        91  40.6         9.0
# 5         Colorado     7.9      204        78  38.7         7.9
# 6      Connecticut     3.3      110        77  11.1         3.3
# 7         Delaware     5.9      238        72  15.8         5.9
# 8          Florida    15.4      335        80  31.9        15.4
# 9          Georgia    17.4      211        60  25.8        17.4
# 10          Hawaii     5.3       46        83  20.2         5.3
# 11           Idaho     2.6      120        54  14.2         2.6
# 12        Illinois    10.4      249        83  24.0        10.4
# 13         Indiana     7.2      113        65  21.0         7.2
# ...

# %%
state.isna().sum()
# Out:
# State       0
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
cols=["c1","c2","c3","c4","c5"]
rows=["r1","r2","r3","r4","r5"]
data= np.random.randint(1,100,size=(5,5))
df= pd.DataFrame(data,columns=cols,index=rows)
df
# Out:
#     c1  c2  c3  c4  c5
# r1  36   5  53  24  91
# r2  54  69  44  91   5
# r3  88  50  41  95  21
# r4  74  66  57  19  32
# r5  54  29  47  59  67

# %%
df.iloc[1,3]=np.nan
df.iloc[1,1]=0
df.c5=np.nan

# %%
df
# Out:
#     c1  c2  c3    c4  c5
# r1  36   5  53  24.0 NaN
# r2  54   0  44   NaN NaN
# r3  88  50  41  95.0 NaN
# r4  74  66  57  19.0 NaN
# r5  54  29  47  59.0 NaN

# %%
df.loc[:,df.all()]
# Out:
#     c1  c3    c4  c5
# r1  36  53  24.0 NaN
# r2  54  44   NaN NaN
# r3  88  41  95.0 NaN
# r4  74  57  19.0 NaN
# r5  54  47  59.0 NaN

# %%
df.loc[:,df.any()]
# Out:
#     c1  c2  c3    c4
# r1  36   5  53  24.0
# r2  54   0  44   NaN
# r3  88  50  41  95.0
# r4  74  66  57  19.0
# r5  54  29  47  59.0

# %%
df.loc[:,df.isnull().any()]
# Out:
#       c4  c5
# r1  24.0 NaN
# r2   NaN NaN
# r3  95.0 NaN
# r4  19.0 NaN
# r5  59.0 NaN

# %%
df.loc[:,df.isnull().all()]
# Out:
#     c5
# r1 NaN
# r2 NaN
# r3 NaN
# r4 NaN
# r5 NaN

# %%
df.dropna(how="all",axis=0)
# Out:
#     c1  c2  c3    c4  c5
# r1  36   5  53  24.0 NaN
# r2  54   0  44   NaN NaN
# r3  88  50  41  95.0 NaN
# r4  74  66  57  19.0 NaN
# r5  54  29  47  59.0 NaN

# %%
df.fillna(11)
# Out:
#     c1  c2  c3    c4    c5
# r1  36   5  53  24.0  11.0
# r2  54   0  44  11.0  11.0
# r3  88  50  41  95.0  11.0
# r4  74  66  57  19.0  11.0
# r5  54  29  47  59.0  11.0

# %%
import random
stu_random= pd.DataFrame({
    "Div":[random.choice(("A","B","C")) for i in range(100000)],
    "col1":[random.randint(1,10) for i in range(100000)],
    "col2":[random.randint(1,10) for i in range(100000)]
})

# %%
stu_random
# Out:
#       Div  col1  col2
# 0       B    10     3
# 1       C     9     4
# 2       A     8     8
# 3       B     4     8
# 4       B     4     6
# ...    ..   ...   ...
# 99995   C     2     6
# 99996   C     4     6
# 99997   A     4     9
# 99998   C     9     3
# 99999   A     3     5
#
# [100000 rows x 3 columns]

# %%
stu_random[stu_random["Div"]=="A"].mean()
# Out:
# C:\Users\MSCIT\AppData\Local\Temp/ipykernel_9548/2171436358.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stu_random[stu_random["Div"]=="A"].mean()
# col1    5.506632
# col2    5.540595
# dtype: float64

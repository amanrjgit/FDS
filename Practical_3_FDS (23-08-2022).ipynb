# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
cars_data=pd.read_csv("Datasets/toyota.csv",index_col=0,na_values=["??","????"])
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
cars_data.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
cars_data["HP"].unique()
# Out:
# array([ 90.,  nan, 192., 110.,  97.,  71., 116.,  98.,  69.,  86.,  72.,
#        107.,  73.])

# %%
cars_data["Doors"].unique()
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
sns.scatterplot(cars_data["Age"],cars_data["Price"],markers="#")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(cars_data["Age"],cars_data["Price"],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x="Age",y="Price",data=cars_data,hue="FuelType",palette="PuRd_r",fit_reg=False)

# %%
sns.distplot(cars_data.Age,kde=False,bins=8)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(data=cars_data,x="FuelType",palette="PuRd_r",hue="Automatic")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars_data["Automatic"],columns=cars_data["FuelType"],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
sns.boxplot(cars_data.FuelType,cars_data.Price,hue=cars_data["Automatic"])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
fig, axes = plt.subplots(1, 2)

#create boxplot in each subplot
sns.boxplot(data=cars_data, x='Age', y='HP', ax=axes[0])
sns.boxplot(data=cars_data, x='Age', y='Price', ax=axes[1])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={'height_ratios':(.4,.6)})

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={'height_ratios':(.4,.6)})
sns.boxplot(x=cars_data.Price,ax=ax_box)
sns.histplot(x=cars_data.Price,ax=ax_hist)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.pairplot(cars_data,kind="scatter",hue="FuelType",diag_kws={"bw_method":0.1})

# %%
randomdata=np.random.randint(20,100,(10,10))
print("Data to be plotted: ")
print(randomdata)
sns.heatmap(randomdata)
# Out:
# Data to be plotted:
# [[90 57 95 50 61 35 70 21 92 62]
#  [24 29 60 33 35 99 73 69 73 45]
#  [35 52 74 23 54 56 76 34 57 73]
#  [65 70 99 98 38 40 67 59 68 81]
#  [38 38 33 56 75 70 20 37 69 55]
#  [53 81 72 57 20 64 49 42 30 35]
#  [36 48 20 62 34 93 38 68 40 87]
#  [27 82 93 37 98 83 22 46 42 41]
#  [78 56 66 20 50 87 57 25 68 75]
#  [90 41 80 45 68 86 96 95 33 74]]
# <AxesSubplot:>

# %%
sns.heatmap(randomdata,vmin=30,vmax=70)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(randomdata,cmap="rocket",annot=True)
# Out:
# <AxesSubplot:>
